# %% [markdown]
# <a href="https://colab.research.google.com/github/JoseGuarnizo/ejemploPANDAS/blob/master/PANDAS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
import numpy as np
import os
import csv
import io
import json
import ast
import datetime as dt
from pandas.io.json import json_normalize 
from pandas import Series, DataFrame
from ast import literal_eval

# %%
#Cargar data desde la maquina local a colab
from google.colab import files

carga = files.upload()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-07da9d7629ed> in <module>
#       1 #Cargar data desde la maquina local a colab
# ----> 2 from google.colab import files
#       3
#       4 carga = files.upload()
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
#Proceso de Extracción

#Carga data en una variable
carga = pd.read_csv('df.csv', names='uno')

# %%
#convertir en list y despues en json
data2 = list(carga['u'])
da = []
for i in range(0,len(data2)):
    d = data2[i].split('.gz:')
    da.append(json.loads((d[1])))

# %%
#Construcción DataFrame
new_data = pd.DataFrame(da)
new_data
# Out:
#     username event_source                             name  \
# 0                  server  edx.course.enrollment.activated
# 1                  server                              NaN
# 2                  server                              NaN
# 3                  server                              NaN
# 4                  server                              NaN
# ..       ...          ...                              ...
# 995     dicc       server                              NaN
# 996     dicc       server                              NaN
# 997     dicc       server  edx.course.enrollment.activated
# 998     dicc       server                              NaN
# 999                server                              NaN
#
#                                        accept_language  \
# 0
# 1
# 2                                       es-ES,es;q=0.8
# 3                                       es-ES,es;q=0.8
# 4    es-MX,es-ES;q=0.9,es;q=0.7,es-AR;q=0.6,es-CL;q...
# ..                                                 ...
# 995                                     es-ES,es;q=0.9
# 996                                     es-ES,es;q=0.9
# 997                                     es-ES,es;q=0.9
# 998                                     es-ES,es;q=0.9
# 999                es-ES,es;q=0.8,en-US;q=0.5,en;q=0.3
#
#                                  time  \
# 0    2017-11-10T14:34:24.674569+00:00
# 1    2017-11-10T15:01:30.054897+00:00
# 2    2017-11-10T15:32:28.277486+00:00
# 3    2017-11-10T15:32:29.041853+00:00
# 4    2017-11-10T16:58:38.328698+00:00
# ..                                ...
# 995  2017-11-21T22:09:11.659918+00:00
# 996  2017-11-21T22:10:03.295806+00:00
# 997  2017-11-21T22:10:03.370828+00:00
# 998  2017-11-21T22:10:03.460488+00:00
# 999  2017-11-21T22:13:04.978585+00:00
#
#                                                  agent  page  \
# 0                                                       None
# 1    Mozilla/5.0 (compatible; Googlebot/2.1; +http:...  None
# 2    Mozilla/5.0 (Windows NT 6.3; Win64; x64) Apple...  None
# 3    Mozilla/5.0 (Windows NT 6.3; Win64; x64) Apple...  None
# 4    Mozilla/5.0 (Windows NT 6.3; Win64; x64; rv:56...  None
# ..                                                 ...   ...
# 995  Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...  None
# 996  Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...  None
# 997  Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...  None
# 998  Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...  None
# 999  Mozilla/5.0 (Windows NT 6.3; Win64; x64; rv:57...  None
#
#                        host                           session  \
# 0
# 1    opencampus.utpl.edu.ec                               NaN
# 2    opencampus.utpl.edu.ec                               NaN
# 3    opencampus.utpl.edu.ec                               NaN
# 4    opencampus.utpl.edu.ec                               NaN
# ..                      ...                               ...
# 995  opencampus.utpl.edu.ec                               NaN
# 996  opencampus.utpl.edu.ec                               NaN
# 997  opencampus.utpl.edu.ec  de392f4f4c86f2f331622df99d0275f1
# 998  opencampus.utpl.edu.ec                               NaN
# 999  opencampus.utpl.edu.ec                               NaN
#
#                                                referer  \
# 0
# 1
# 2                       http://opencampus.utpl.edu.ec/
# 3    http://opencampus.utpl.edu.ec/courses/course-v...
# 4                       http://opencampus.utpl.edu.ec/
# ..                                                 ...
# 995  http://opencampus.utpl.edu.ec/courses/course-v...
# 996  http://opencampus.utpl.edu.ec/courses/course-v...
# 997  http://opencampus.utpl.edu.ec/courses/course-v...
# 998  http://opencampus.utpl.edu.ec/courses/course-v...
# 999                     http://opencampus.utpl.edu.ec/
#
#                                                context               ip  \
# 0    {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DI...
# 1    {'course_user_tags': {}, 'user_id': '', 'org_i...     66.249.64.64
# 2    {'course_user_tags': {}, 'user_id': '', 'org_i...  190.110.206.116
# 3    {'user_id': '', 'org_id': '', 'course_id': '',...  190.110.206.116
# 4    {'course_user_tags': {}, 'user_id': '', 'org_i...     172.17.24.79
# ..                                                 ...              ...
# 995  {'user_id': 13907, 'org_id': '', 'course_id': ...   200.125.216.91
# 996  {'user_id': 13907, 'org_id': '', 'course_id': ...   200.125.216.91
# 997  {'user_id': 13907, 'org_id': 'UTPL', 'course_i...   200.125.216.91
# 998  {'user_id': 13907, 'org_id': '', 'course_id': ...   200.125.216.91
# 999  {'course_user_tags': {}, 'user_id': '', 'org_i...    186.4.211.103
#
#                                                  event  \
# 0    {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DI...
# 1                              {"POST": {}, "GET": {}}
# 2                              {"POST": {}, "GET": {}}
# 3                              {"POST": {}, "GET": {}}
# 4                              {"POST": {}, "GET": {}}
# ..                                                 ...
# 995                            {"POST": {}, "GET": {}}
# 996  {"POST": {"course_id": ["course-v1:UTPL+EFHE-E...
# 997  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DI...
# 998                            {"POST": {}, "GET": {}}
# 999                            {"POST": {}, "GET": {}}
#
#                                           event_type
# 0                    edx.course.enrollment.activated
# 1    /courses/course-v1:UTPL+EFHE-Ed7+2017_DIC/about
# 2    /courses/course-v1:UTPL+EFHE-Ed7+2017_DIC/about
# 3                                           /i18n.js
# 4    /courses/course-v1:UTPL+EFHE-Ed7+2017_DIC/about
# ..                                               ...
# 995                                         /i18n.js
# 996                               /change_enrollment
# 997                  edx.course.enrollment.activated
# 998                                       /dashboard
# 999  /courses/course-v1:UTPL+EFHE-Ed7+2017_DIC/about
#
# [1000 rows x 14 columns]

# %%
#Información de todo el DataFrame
new_data.columns
new_data.shape
new_data.dtypes
# Out:
# username           object
# event_source       object
# name               object
# accept_language    object
# time               object
# agent              object
# page               object
# host               object
# session            object
# referer            object
# context            object
# ip                 object
# event              object
# event_type         object
# dtype: object

# %%
#Verificación de tipo de datos por columna
new_data['event_type'].head()
# Out:
# 0                    edx.course.enrollment.activated
# 1    /courses/course-v1:UTPL+EFHE-Ed7+2017_DIC/about
# 2    /courses/course-v1:UTPL+EFHE-Ed7+2017_DIC/about
# 3                                           /i18n.js
# 4    /courses/course-v1:UTPL+EFHE-Ed7+2017_DIC/about
# Name: event_type, dtype: object

# %%
#Proceso de Transformación
#Eliminar columnas que no son necesarias
new_infor = new_data.drop(['accept_language', 'agent', 'page',
                           'session', 'event_type'], axis=1)

# %%
#Verificar nuevamente la data
new_infor.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
# username        1000 non-null object
# event_source    1000 non-null object
# name            89 non-null object
# time            1000 non-null object
# host            1000 non-null object
# referer         1000 non-null object
# context         1000 non-null object
# ip              1000 non-null object
# event           1000 non-null object
# dtypes: object(9)
# memory usage: 70.4+ KB

# %%
#Proceso Transformacion

#Dividir columna context

contextData = new_infor['context'].values.tolist()

new_contextData = pd.DataFrame(contextData, columns= ['course_user_tags',
                                                      'course_id', 'path',
                                                      'org_id', 'user_id'])

new_contextInfo = new_contextData.drop(['course_user_tags', 'course_id',
                                        'path'], axis=1)
new_contextInfo
# Out:
#     org_id user_id
# 0     UTPL     NaN
# 1     UTPL
# 2     UTPL
# 3
# 4     UTPL
# ..     ...     ...
# 995          13907
# 996          13907
# 997   UTPL   13907
# 998          13907
# 999   UTPL
#
# [1000 rows x 2 columns]

# %%
#Proceso de Transformación
import json 
#Dividir columna event
dat = new_data['event'].values.tolist()
valore = []
for i in range(0,len(dat)):
    if (type(dat[i])==str):
        try:
            valor = json.loads(dat[i])
        except ValueError as e:
            print('mal')
        dat[i]=valor
        valore.append(dat[i])
    else:
        valore.append(dat[i])
# Out:
# mal
# mal
# mal
# mal
# mal
# mal
# mal

# %%
valore
# Out:
# [{'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 258,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'notifyOnError': ['false']}, 'GET': {}},
#  {'POST': {'notifyOnError': ['false']}, 'GET': {}},
#  {'POST': {},
#   'GET': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 13748,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 13802,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 13804,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 5521,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 13653,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 13743,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 10779,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'POST': {},
#   'GET': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']}},
#  {'POST': {},
#   'GET': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll'],
#    'next': ['/dashboard']}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 13806,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 13807,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 2447,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 13812,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 13813,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'POST': {},
#   'GET': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 11201,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'POST': {},
#   'GET': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']}},
#  {'POST': {'username': ['Sara Gaibor'],
#    'city': ['Guaranda'],
#    'name': ['Sara Lisbeth Gaibor Camacho'],
#    'gender': ['f'],
#    'year_of_birth': ['1993'],
#    'level_of_education': ['hs'],
#    'goals': ['Por quiero conocer más sobre los alimentos y asi tener una buena alimentación.'],
#    'honor_code': ['true'],
#    'country': ['EC'],
#    'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'password': '********',
#    'mailing_address': ['1723869903'],
#    'email': ['sarigaibor_20@yahoo.es']},
#   'GET': {}},
#  {'POST': {},
#   'GET': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll'],
#    'next': ['/dashboard']}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 13792,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 13725,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'POST': {},
#   'GET': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']}},
#  {'POST': {},
#   'GET': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll'],
#    'next': ['/dashboard']}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 1474,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 10691,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 13793,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'POST': {},
#   'GET': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']}},
#  {'POST': {'analytics': ['{"enroll_course_id":"course-v1:UTPL+EFHE-Ed7+2017_DIC"}'],
#    'password': '********',
#    'email': ['jpyaguana@utpl.edu.ec'],
#    'remember': ['false']},
#   'GET': {}},
#  {'POST': {},
#   'GET': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll'],
#    'next': ['/dashboard']}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 7429,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 13818,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'POST': {},
#   'GET': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'POST': {},
#   'GET': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'username': ['Estrella Pillco'],
#    'city': ['cuenca'],
#    'name': ['Estrella Pillco'],
#    'gender': ['f'],
#    'year_of_birth': ['1996'],
#    'level_of_education': ['hs'],
#    'goals': ['porque es un beneficio para mi trabajo'],
#    'honor_code': ['true'],
#    'country': ['EC'],
#    'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'password': '********',
#    'mailing_address': ['0105550230'],
#    'email': ['estrella.pillco@yahoo.com']},
#   'GET': {}},
#  {'POST': {'username': ['Estrella Pillco'],
#    'city': ['cuenca'],
#    'name': ['Estrella pillco'],
#    'gender': ['f'],
#    'year_of_birth': ['1996'],
#    'level_of_education': ['hs'],
#    'goals': ['porque es un beneficio para mi trabajo'],
#    'honor_code': ['true'],
#    'country': ['EC'],
#    'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'password': '********',
#    'mailing_address': ['0105550230'],
#    'email': ['estrella.pillco@yahoo.com']},
#   'GET': {}},
#  {'POST': {'username': ['Estrella Pillco'],
#    'city': ['cuenca'],
#    'name': ['Estrella pillco'],
#    'gender': ['f'],
#    'year_of_birth': ['1996'],
#    'level_of_education': ['hs'],
#    'goals': ['porque es un beneficio para mi trabajo'],
#    'honor_code': ['true'],
#    'country': ['EC'],
#    'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'password': '********',
#    'mailing_address': ['0105550230'],
#    'email': ['estrella.pillco@yahoo.com']},
#   'GET': {}},
#  {'POST': {'username': ['Estrella Pillco'],
#    'city': ['cuenca'],
#    'name': ['Estrella pillco'],
#    'gender': ['f'],
#    'year_of_birth': ['1996'],
#    'level_of_education': ['hs'],
#    'goals': ['porque es un beneficio para mi trabajo'],
#    'honor_code': ['true'],
#    'country': ['EC'],
#    'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'password': '********',
#    'mailing_address': ['0105550230'],
#    'email': ['estrella.pillco@yahoo.com']},
#   'GET': {}},
#  {'POST': {'username': ['Estrella_Pillco'],
#    'city': ['cuenca'],
#    'name': ['Estrella pillco'],
#    'gender': ['f'],
#    'year_of_birth': ['1996'],
#    'level_of_education': ['hs'],
#    'goals': ['porque es un beneficio para mi trabajo'],
#    'honor_code': ['true'],
#    'country': ['EC'],
#    'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'password': '********',
#    'mailing_address': ['0105550230'],
#    'email': ['estrella.pillco@yahoo.com']},
#   'GET': {}},
#  {'POST': {},
#   'GET': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll'],
#    'next': ['/dashboard']}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 13819,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'POST': {},
#   'GET': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']}},
#  {'POST': {'username': ['Javier_Ordoñez'],
#    'city': ['cuenca'],
#    'name': ['Javier Ordoñez'],
#    'gender': ['m'],
#    'year_of_birth': ['1998'],
#    'level_of_education': ['hs'],
#    'goals': ['por el beneficio que obtengo en mi trabajo '],
#    'honor_code': ['true'],
#    'country': ['EC'],
#    'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'password': '********',
#    'mailing_address': ['0107406993'],
#    'email': ['javieroc_98@hotmail.com']},
#   'GET': {}},
#  {'POST': {'username': ['Javier _ Ordoñez'],
#    'city': ['cuenca'],
#    'name': ['Javier Ordoñez'],
#    'gender': ['m'],
#    'year_of_birth': ['1998'],
#    'level_of_education': ['hs'],
#    'goals': ['por el beneficio que obtengo en mi trabajo '],
#    'honor_code': ['true'],
#    'country': ['EC'],
#    'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'password': '********',
#    'mailing_address': ['0107406993'],
#    'email': ['javieroc_98@hotmail.com']},
#   'GET': {}},
#  {'POST': {'username': ['Javier-Ordoñez'],
#    'city': ['cuenca'],
#    'name': ['Javier Ordoñez'],
#    'gender': ['m'],
#    'year_of_birth': ['1998'],
#    'level_of_education': ['hs'],
#    'goals': ['por el beneficio que obtengo en mi trabajo '],
#    'honor_code': ['true'],
#    'country': ['EC'],
#    'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'password': '********',
#    'mailing_address': ['0107406993'],
#    'email': ['javieroc_98@hotmail.com']},
#   'GET': {}},
#  {'POST': {'username': ['Javier-Ordoñez'],
#    'city': ['cuenca'],
#    'name': ['Javier-Ordoñez'],
#    'gender': ['m'],
#    'year_of_birth': ['1998'],
#    'level_of_education': ['hs'],
#    'goals': ['por el beneficio que obtengo en mi trabajo '],
#    'honor_code': ['true'],
#    'country': ['EC'],
#    'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'password': '********',
#    'mailing_address': ['0107406993'],
#    'email': ['javieroc_98@hotmail.com']},
#   'GET': {}},
#  {'POST': {'username': ['Javier_Ordonez'],
#    'city': ['cuenca'],
#    'name': ['Javier-Ordoñez'],
#    'gender': ['m'],
#    'year_of_birth': ['1998'],
#    'level_of_education': ['hs'],
#    'goals': ['por el beneficio que obtengo en mi trabajo '],
#    'honor_code': ['true'],
#    'country': ['EC'],
#    'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'password': '********',
#    'mailing_address': ['0107406993'],
#    'email': ['javieroc_98@hotmail.com']},
#   'GET': {}},
#  {'POST': {},
#   'GET': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll'],
#    'next': ['/dashboard']}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 13821,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 3502,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 8644,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'POST': {},
#   'GET': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']}},
#  {'POST': {'analytics': ['{"enroll_course_id":"course-v1:UTPL+EFHE-Ed7+2017_DIC"}'],
#    'password': '********',
#    'email': ['nicolearo@hotmail.com'],
#    'remember': ['false']},
#   'GET': {}},
#  {'POST': {},
#   'GET': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll'],
#    'next': ['/dashboard']}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 10208,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'POST': {},
#   'GET': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 13799,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 13780,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 7028,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 10838,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 8349,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 13829,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 1648,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'POST': {},
#   'GET': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']}},
#  {'POST': {'analytics': ['{"enroll_course_id":"course-v1:UTPL+EFHE-Ed7+2017_DIC"}'],
#    'password': '********',
#    'email': ['scarv_017@hotmail.com'],
#    'remember': ['false']},
#   'GET': {}},
#  {'POST': {},
#   'GET': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll'],
#    'next': ['/dashboard']}},
#  {'POST': {}, 'GET': {}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 2978,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 11123,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 13444,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 9949,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'POST': {},
#   'GET': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']}},
#  {'POST': {'analytics': ['{"enroll_course_id":"course-v1:UTPL+EFHE-Ed7+2017_DIC"}'],
#    'password': '********',
#    'email': ['shalom19812003@hotmail.com'],
#    'remember': ['true']},
#   'GET': {}},
#  {'POST': {'analytics': ['{"enroll_course_id":"course-v1:UTPL+EFHE-Ed7+2017_DIC"}'],
#    'password': '********',
#    'email': ['shalom19812003@hotmail.com'],
#    'remember': ['true']},
#   'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'POST': {},
#   'GET': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']}},
#  {'POST': {'username': ['msmartinez4'],
#    'city': ['Quito'],
#    'name': ['Maria Soledad Martinez Monge'],
#    'gender': ['f'],
#    'year_of_birth': ['1981'],
#    'level_of_education': ['hs'],
#    'goals': ['quiero aprender mas'],
#    'honor_code': ['true'],
#    'country': ['EC'],
#    'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'password': '********',
#    'mailing_address': ['1717258253'],
#    'email': ['shalom19812003@hotmail.com']},
#   'GET': {}},
#  {'POST': {},
#   'GET': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll'],
#    'next': ['/dashboard']}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 13836,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 13837,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['unenroll']},
#   'GET': {}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 13837,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 5939,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 13842,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 13766,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 2107,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 2480,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 8503,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 11076,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 13820,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 13851,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 2608,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 1588,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'POST': {},
#   'GET': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 1829,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'POST': {},
#   'GET': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']}},
#  {'POST': {'username': ['BELENPIEDRA'],
#    'city': ['LOJA'],
#    'name': ['MARIA BELEN PIEDRA SIZALIMA'],
#    'gender': ['f'],
#    'year_of_birth': ['1991'],
#    'level_of_education': ['m'],
#    'goals': ['COMPLETAR CREDITOS'],
#    'honor_code': ['true'],
#    'country': ['EC'],
#    'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'password': '********',
#    'mailing_address': ['1105232605'],
#    'email': ['belupiedra@gmail.com']},
#   'GET': {}},
#  {'POST': {'username': ['MBELENPIEDRA'],
#    'city': ['LOJA'],
#    'name': ['MARIA BELEN PIEDRA SIZALIMA'],
#    'gender': ['f'],
#    'year_of_birth': ['1991'],
#    'level_of_education': ['m'],
#    'goals': ['COMPLETAR CREDITOS'],
#    'honor_code': ['true'],
#    'country': ['EC'],
#    'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'password': '********',
#    'mailing_address': ['1105232605'],
#    'email': ['belupiedra@gmail.com']},
#   'GET': {}},
#  {'POST': {},
#   'GET': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll'],
#    'next': ['/dashboard']}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 13857,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 13858,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 13489,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 7214,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'POST': {},
#   'GET': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']}},
#  {'POST': {'analytics': ['{"enroll_course_id":"course-v1:UTPL+EFHE-Ed7+2017_DIC"}'],
#    'password': '********',
#    'email': ['magaby-15@hotmail.com'],
#    'remember': ['false']},
#   'GET': {}},
#  {'POST': {'analytics': ['{"enroll_course_id":"course-v1:UTPL+EFHE-Ed7+2017_DIC"}'],
#    'password': '********',
#    'email': ['magaby-15@hotmail.com'],
#    'remember': ['false']},
#   'GET': {}},
#  {'POST': {},
#   'GET': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll'],
#    'next': ['/dashboard']}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 5603,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 10170,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 7479,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'POST': {},
#   'GET': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']}},
#  {'POST': {},
#   'GET': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']}},
#  {'POST': {},
#   'GET': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'POST': {},
#   'GET': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'POST': {},
#   'GET': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 13861,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'username': ['maguzman16'],
#    'city': ['cuenca'],
#    'name': ['Monica Andrea Guzman Almeida '],
#    'gender': ['f'],
#    'year_of_birth': ['1990'],
#    'level_of_education': ['m'],
#    'goals': ['quiero seguir preparandome'],
#    'honor_code': ['true'],
#    'country': ['EC'],
#    'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'password': '********',
#    'mailing_address': ['0103825303'],
#    'email': ['monicaguz11@gmail.com']},
#   'GET': {}},
#  {'POST': {},
#   'GET': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll'],
#    'next': ['/dashboard']}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 13862,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 6763,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 11175,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'POST': {},
#   'GET': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']}},
#  {'POST': {'analytics': ['{"enroll_course_id":"course-v1:UTPL+EFHE-Ed7+2017_DIC"}'],
#    'password': '********',
#    'email': ['deyalan@yahoo.es'],
#    'remember': ['false']},
#   'GET': {}},
#  {'POST': {},
#   'GET': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll'],
#    'next': ['/dashboard']}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 1178,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'POST': {},
#   'GET': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']}},
#  {'POST': {},
#   'GET': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll'],
#    'next': ['/dashboard']}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 12186,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 7161,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'POST': {},
#   'GET': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 504,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 13874,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 10058,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 6569,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'POST': {},
#   'GET': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']}},
#  {'POST': {},
#   'GET': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll'],
#    'next': ['/dashboard']}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 10365,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 12368,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 3771,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'POST': {},
#   'GET': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']}},
#  {'POST': {},
#   'GET': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll'],
#    'next': ['/dashboard']}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 12341,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 3866,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'POST': {},
#   'GET': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']}},
#  {'POST': {'username': ['sefreire1'],
#    'city': ['Quito'],
#    'name': ['Estefanía FReire'],
#    'gender': ['f'],
#    'year_of_birth': ['1984'],
#    'level_of_education': ['b'],
#    'goals': ['Porque estoy interesada en aprender más sobre alimentación saludable'],
#    'honor_code': ['true'],
#    'country': ['EC'],
#    'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'password': '********',
#    'mailing_address': ['1717528416'],
#    'email': ['estefania_freirev@hotmail.com']},
#   'GET': {}},
#  {'POST': {},
#   'GET': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll'],
#    'next': ['/dashboard']}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 13880,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 4994,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 164,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 11158,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 11868,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 13777,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 13891,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 1130,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 5591,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 13892,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 13881,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 2535,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'POST': {},
#   'GET': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']}},
#  {'POST': {},
#   'GET': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']}},
#  {'POST': {},
#   'GET': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']}},
#  {'POST': {},
#   'GET': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']}},
#  {'POST': {},
#   'GET': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']}},
#  {'POST': {},
#   'GET': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll'],
#    'next': ['/dashboard']}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 13905,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'POST': {},
#   'GET': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}},
#  {'POST': {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_DIC'],
#    'enrollment_action': ['enroll']},
#   'GET': {}},
#  {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC',
#   'user_id': 13907,
#   'mode': 'honor'},
#  {'POST': {}, 'GET': {}},
#  {'POST': {}, 'GET': {}}]

# %%
pd.DataFrame.from_records(valore)
# Out:
#                             course_id  user_id   mode  \
# 0    course-v1:UTPL+EFHE-Ed7+2017_DIC    258.0  honor
# 1                                 NaN      NaN    NaN
# 2                                 NaN      NaN    NaN
# 3                                 NaN      NaN    NaN
# 4                                 NaN      NaN    NaN
# ..                                ...      ...    ...
# 995                               NaN      NaN    NaN
# 996                               NaN      NaN    NaN
# 997  course-v1:UTPL+EFHE-Ed7+2017_DIC  13907.0  honor
# 998                               NaN      NaN    NaN
# 999                               NaN      NaN    NaN
#
#                                                   POST  GET
# 0                                                  NaN  NaN
# 1                                                   {}   {}
# 2                                                   {}   {}
# 3                                                   {}   {}
# 4                                                   {}   {}
# ..                                                 ...  ...
# 995                                                 {}   {}
# 996  {'course_id': ['course-v1:UTPL+EFHE-Ed7+2017_D...   {}
# 997                                                NaN  NaN
# 998                                                 {}   {}
# 999                                                 {}   {}
#
# [1000 rows x 5 columns]
